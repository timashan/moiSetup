# %% [markdown]
# # xkcd

# %%
import numpy as np

import matplotlib.pyplot as plt
import matplotlib
import shutil

# %% [markdown]
# `Install the Fonts to get rid of the ultra annoying warnings`

# %% [markdown]
# Clear the matplotlib cache, mayb restart kernel & try again

# %%
shutil.rmtree(matplotlib.get_cachedir())

# %%
x = np.linspace(0, 10, 1000)
y = np.sin(x)

with plt.xkcd():
    fig, ax = plt.subplots()
    ax.plot(x, y)
